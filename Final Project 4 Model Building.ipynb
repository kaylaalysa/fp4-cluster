# %% [markdown]
# # Import Library

# %%
import numpy as np
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
pd.set_option('display.max_columns', None)
# %matplotlib inline

# %% [markdown]
# # Import Data Set and Inspect

# %%
df = pd.read_csv('CC GENERAL.csv')

# %%
#First Row 
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
#Data Set Info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
#Missing Data in The Data Set 
(df.isnull().sum()/len(df))*100
# Out:
# CUST_ID                             0.000000
# BALANCE                             0.000000
# BALANCE_FREQUENCY                   0.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.011173
# PAYMENTS                            0.000000
# MINIMUM_PAYMENTS                    3.497207
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              0.000000
# dtype: float64

# %%
#Filling Missing Data for Columns 
df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].median(), inplace=True)
df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].median(), inplace=True)

# %% [markdown]
# # Model Building

# %%
#Data For Clustering 
df_model = df.drop('CUST_ID', axis=1)
df_model.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
#Scaled the Data 
from sklearn.preprocessing import StandardScaler 

df_model_scld = StandardScaler().fit_transform(df_model)
df_model_scaled = pd.DataFrame(df_model_scld,columns = df_model.columns)

# %%
#Inspect Scaled Data 
df_model_scaled
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    -0.731989          -0.249434  -0.424900         -0.356934
# 1     0.786961           0.134325  -0.469552         -0.356934
# 2     0.447135           0.518084  -0.107668          0.108889
# 3     0.049099          -1.016953   0.232058          0.546189
# 4    -0.358775           0.518084  -0.462063         -0.347294
# ...        ...                ...        ...               ...
# 8945 -0.737950           0.518084  -0.333293         -0.356934
# 8946 -0.742423           0.518084  -0.329136         -0.356934
# 8947 -0.740398          -0.185477  -0.401965         -0.356934
# 8948 -0.745174          -0.185477  -0.469552         -0.356934
# 8949 -0.572575          -0.889033   0.042146          0.301732
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                  -0.349079     -0.466786            -0.806490
# 1                  -0.454576      2.605605            -1.221758
# ...

# %%
#Finding Number of Cluster using Elbow Method 
#Inertia
from sklearn.cluster import KMeans
inertia = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(df_model_scaled.values)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(20, 10))

sns.lineplot(x=range(1, 11), y=inertia, color='#000087', linewidth = 4)
sns.scatterplot(x=range(1, 11), y=inertia, s=300, color='#800000',  linestyle='--')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Conclusion:** For Elbow Method It Can Be Conluded that there are 4 potential Cluster in the Data Set.

# %%
#Train the Model 
kmeans = KMeans(n_clusters=4, random_state=42).fit(df_model_scaled)

# %%
#Cluster Fitting 
df_cluster = pd.DataFrame(data=df_model_scaled, columns=df_model_scaled.columns)
df_cluster['cluster'] = kmeans.labels_
df_cluster
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    -0.731989          -0.249434  -0.424900         -0.356934
# 1     0.786961           0.134325  -0.469552         -0.356934
# 2     0.447135           0.518084  -0.107668          0.108889
# 3     0.049099          -1.016953   0.232058          0.546189
# 4    -0.358775           0.518084  -0.462063         -0.347294
# ...        ...                ...        ...               ...
# 8945 -0.737950           0.518084  -0.333293         -0.356934
# 8946 -0.742423           0.518084  -0.329136         -0.356934
# 8947 -0.740398          -0.185477  -0.401965         -0.356934
# 8948 -0.745174          -0.185477  -0.469552         -0.356934
# 8949 -0.572575          -0.889033   0.042146          0.301732
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                  -0.349079     -0.466786            -0.806490
# 1                  -0.454576      2.605605            -1.221758
# ...

# %%
#PCA Cluster Evaluation 
# PCA for Visualization
from sklearn.decomposition import PCA 
pca = PCA(n_components=2)

pca.fit(df_model_scaled)
pcs = pca.transform(df_model_scaled)

data_pca = pd.DataFrame(data = pcs, columns = ['PC 1', 'PC 2'])
data_pca['clusters'] = df_cluster['cluster']
data_pca.head()
# Out:
#        PC 1      PC 2  clusters
# 0 -1.744845 -0.956188         2
# 1 -1.202482  2.396219         1
# 2  1.102466 -0.523815         0
# 3 -1.011226  0.193566         2
# 4 -1.674288 -0.572147         2

# %%
#Visualize PCA 
#Plot PCA
fig, ax = plt.subplots(figsize=(15,10))

sns.scatterplot(
    x="PC 1", y="PC 2",
    hue="clusters",
    edgecolor=None,
    linestyle='--',
    data=data_pca,
    palette=['blue','red', 'purple', 'orange'],
    s=160,
    ax=ax
)
# Out:
# <AxesSubplot:xlabel='PC 1', ylabel='PC 2'>

# %% [markdown]
# **Conclusion:** The Cluster Looks Fairly Seperated from Each Other Despite There are some overlap in the data

# %%
#Merge Cluster to Original Data Set 
df_model['cluster'] = kmeans.labels_
df_model.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
#Column List 
list_column = df_model.columns.tolist()

# %%
#Aggregation for Defining Each Cluster Meaning 
df_model.groupby('cluster')[list_column[0:16]].median()
# Out:
#              BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# cluster
# 0         337.269567                1.0     892.30            168.54
# 1        4274.488095                1.0      85.54              0.00
# 2         764.042156                1.0      79.20              0.00
# 3        2492.726282                1.0    5848.55           3705.13
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# cluster
# 0                        450.67      0.000000             1.000000
# 1                          0.00   3666.845105             0.083333
# 2                          0.00    117.579435             0.083333
# 3                       1827.96      0.000000             1.000000
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# cluster
# 0                          0.111111                          0.833333
# 1                          0.000000                          0.000000
# ...

# %%
import pickle
pickle.dump(kmeans, open('cluster.pkl','wb'))
